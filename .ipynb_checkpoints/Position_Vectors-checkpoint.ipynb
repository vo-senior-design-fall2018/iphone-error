# %%
import json
import csv
import pandas as pd
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt

# %%
initial_df = pd.read_csv('subsetData.csv') #loading sample data (small portion of 10ft data)
print(initial_df)
# Out:
#     SessionID SessionDate SessionDuration  SessionFrequency  RecordID  \
# 0           0     38:58.8            0:23                60         0
# 1           0     38:58.8            0:23                60         0
# 2           0     38:58.8            0:23                60         0
# 3           0     38:58.8            0:23                60         0
# 4           0     38:58.8            0:23                60         0
# 5           0     38:58.8            0:23                60         0
# 6           0     38:58.8            0:23                60         0
# 7           0     38:58.8            0:23                60         0
# 8           0     38:58.8            0:23                60         0
# 9           0     38:58.8            0:23                60         0
# 10          0     38:58.8            0:23                60         0
# 11          0     38:58.8            0:23                60         0
# 12          0     38:58.8            0:23                60         0
# 13          0     38:58.8            0:23                60         0
# 14          0     38:58.8            0:23                60         0
# 15          0     38:58.8            0:23                60         0
# 16          0     38:58.8            0:23                60         0
# 17          0     38:58.8            0:23                60         0
# 18          0     38:58.8            0:23                60         0
# 19          0     38:58.8            0:23                60         0
# 20          0     38:58.8            0:23                60         0
# 21          0     38:58.8            0:23                60         0
# 22          0     38:58.8            0:23                60         0
# 23          0     38:58.8            0:23                60         0
# 24          0     38:58.8            0:23                60         0
# 25          0     38:58.8            0:23                60         0
# 26          0     38:58.8            0:23                60         0
# 27          0     38:58.8            0:23                60         0
# 28          0     38:58.8            0:23                60         0
# 29          0     38:58.8            0:23                60         0
# 30          0     38:58.8            0:23                60         0
# 31          0     38:58.8            0:23                60         0
# 32          0     38:58.8            0:23                60         0
#
#    Timestamp  timeIntervalSince1970     GyroX     GyroY     GyroZ      AccX  \
# 0    38:58.8             1540931939 -0.171711 -0.445727 -0.103311  0.071121
# 1    38:58.9             1540931939 -0.135503 -0.069837 -0.062164  0.024292
# 2    38:58.9             1540931939 -0.058513  0.157536 -0.035130  0.054092
# 3    38:58.9             1540931939  0.010898  0.135294 -0.049095  0.083969
# 4    38:58.9             1540931939  0.029782  0.011873 -0.065315  0.090942
# 5    38:58.9             1540931939 -0.106916 -0.048638 -0.022522  0.076782
# 6    38:58.9             1540931939 -0.173546 -0.073880 -0.041813  0.063354
# 7    38:59.0             1540931939 -0.167952 -0.162411 -0.095467  0.058990
# 8    38:59.0             1540931939 -0.119433 -0.169221 -0.131896  0.057373
# 9    38:59.0             1540931939 -0.054374 -0.100481 -0.167165  0.048523
# 10   38:59.0             1540931939 -0.000636 -0.001373 -0.195969  0.040619
# 11   38:59.0             1540931939  0.001843  0.039661 -0.185211  0.031296
# 12   38:59.0             1540931939  0.001843  0.039661 -0.185211  0.031296
# 13   38:59.1             1540931939 -0.212727  0.111743 -0.114393  0.012527
# 20 -0.181900 -0.960876  39.798843  29.643921 -76.195435
# 21 -0.188324 -0.966812  39.846481  29.712204 -76.190292
# 22 -0.186234 -1.001389  39.832932  29.792755 -76.109970
# 23 -0.176117 -1.019211  39.832932  29.792755 -76.109970
# 24 -0.175339 -1.006622  39.945663  29.849152 -75.711441
# 25 -0.190781 -0.978378  39.714325  30.126938 -76.103973
# 26 -0.208145 -0.949097  39.680878  29.978180 -76.111343
# 27 -0.213531 -0.916550  39.434189  30.027084 -76.044876
# 28 -0.215759 -0.903168  39.459991  29.865845 -76.361710
# 29 -0.220505 -0.915939  39.459991  29.865845 -76.361710
# 30 -0.233414 -0.962677  39.542358  30.083023 -76.193039
# 31 -0.232162 -0.990616  39.338760  30.199768 -76.668106
# 32 -0.228287 -0.982788  39.059265  30.099960 -76.530899

# %% [markdown]
# ## Finding the position vector
# If P is the point with coordinates (x, y, z) then the length, or magnitude, of the position vector
# OP is given by the formula:
# ### |OP|= sqrt(x^2 + y^2 + z^2)
#
# Source: http://www.mathcentre.ac.uk/resources/uploaded/mc-ty-cartesian1-2009-1.pdf

# %%
def square(x):
    return x**2

def positionVector(x, y, z):
    x = square(x)
    y = square(y)
    z = square(z)
    return(abs(sqrt(x + y+ z))) 

final_df = pd.DataFrame(columns=['sumGyro', 'sumAcc', 'sumMag'])
for index, row in initial_df.iterrows():
    final_df.at[index,'sumGyro'] = positionVector(row['GyroX'], row['GyroY'], row['GyroZ']) #get OP of Gyro
    final_df.at[index,'sumAcc'] = positionVector(row['AccX'], row['AccY'], row['AccZ']) #get OP of Acc
    final_df.at[index,'sumMag'] = positionVector(row['MagX'], row['MagY'], row['MagZ']) #get OP of Mag

# %%
print(final_df)
# Out:
#       sumGyro    sumAcc   sumMag
# 0    0.488703   1.06008  91.5085
# 1    0.164628   1.02681  91.3902
# 2    0.171684   1.04381  91.4588
# 3    0.144338   1.04229  91.2951
# 4   0.0727599   1.01753  91.2951
# 5    0.119599   1.00129  91.3024
# 6    0.193196   1.00411  91.3037
# 7    0.252387     1.025  91.4544
# 8    0.245553   1.02232  91.2655
# 9    0.202478  0.997342  91.1115
# 10   0.195975  0.971628  91.1115
# 11   0.189419  0.969905  90.7564
# 12   0.189419  0.969905  90.7974
# 13   0.266129  0.965971  91.1178
# 14   0.266129  0.965971  91.2357
# 15   0.339852   1.02772    91.12
# 16   0.230338   1.06229    91.12
# 17   0.230338   1.06229  91.0431
# 18  0.0918633   1.05297  91.0874
# 19  0.0695049   1.01084  91.1557
# 20   0.184171  0.978032   90.931
# 21   0.273692  0.985205  90.9699
# 22   0.253595   1.01927   90.923
# 23   0.253595   1.03533   90.923
# 24   0.156023   1.02273  90.6579
# 25   0.214005  0.997471  90.9762
# 26   0.214005  0.971742  90.9186
# 27   0.197751   0.94115  90.7717
# 28   0.152534  0.928789  90.9954
# 29   0.193269  0.942195  90.9954
# 30   0.176894  0.990572  90.9613
# 31  0.0792124   1.01752  91.3103
# 32   0.153283   1.00897  91.0418

# %%
print ("sum of Gyro: "+ str(final_df['sumGyro'].sum()))
print ("sum of Acc: "+ str(final_df['sumAcc'].sum()))
print ("sum of Mag: "+ str(final_df['sumMag'].sum()))
# Out:
# sum of Gyro: 6.626323437859389
# sum of Acc: 33.1390241428017
# sum of Mag: 3006.3054821527594

# %% [markdown]
# # Next Steps:
# - Use the pivot point to separate data into two paths
# - Calculate the position vectors for both paths
# - Find the error for the two paths

# %%
ten_feet_df = pd.read_csv('10ft.csv') #loading 10ft full data
gyro_df = pd.read_csv('gyroscope.csv')
print(gyro_df.head())
gyro_x = gyro_df['GyroX']
gyro_y = gyro_df['GyroY']
gyro_z = gyro_df['GyroZ']
gyro_timestamp = gyro_df['Timestamp']
# Out:
#   Timestamp     GyroX     GyroY     GyroZ
# 0   36:12.0  0.028601 -0.440233 -0.064802
# 1   36:12.0  0.019472 -0.407611 -0.086176
# 2   36:12.0 -0.070433 -0.338401 -0.137471
# 3   36:12.0 -0.156878 -0.238931 -0.190870
# 4   36:12.0 -0.236370 -0.071433 -0.232408

# %%
# gyro_df['Timestamp'] = gyro_df['Timestamp'].astype(np.int64) / int(1e6)
# gyro_timestamp = gyro_df['Timestamp']
# print(gyro_timestamp)

# %%
plt.figure(figsize=(16,5))
plt.plot(gyro_timestamp, gyro_x)
plt.plot(gyro_timestamp, gyro_y)
plt.plot(gyro_timestamp, gyro_z)
plt.title('gyroscope')
plt.xlabel('Timestamp')
plt.ylabel('Gyroscope')
plt.show()

# %%
#accelerometer
acc_df = pd.read_csv('accelerometer.csv')
acc_x = acc_df['AccX']
acc_y = acc_df['AccY']
acc_z = acc_df['AccZ']
acc_timestamp = acc_df['Timestamp']

# %%
plt.figure(figsize=(16,5))
plt.plot(acc_timestamp, acc_x)
plt.plot(acc_timestamp, acc_y)
plt.plot(acc_timestamp, acc_z)
plt.title('accelerometer')
plt.xlabel('Timestamp')
plt.ylabel('Accelerometer')
plt.show()

# %%
#mag
mag_df = pd.read_csv('mag.csv')
mag_x = mag_df['MagX']
mag_y = mag_df['MagY']
mag_z = mag_df['MagZ']
mag_timestamp = mag_df['Timestamp']

# %%
plt.figure(figsize=(16,5))
plt.plot(mag_timestamp, mag_x)
plt.plot(mag_timestamp, mag_y)
plt.plot(mag_timestamp, mag_z)
plt.title('mag')
plt.xlabel('Timestamp')
plt.ylabel('mag')
plt.show()
